# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# ## Lab 18
# 1. WAP to perfrom decision tree regression using diabetes dataset and find RMSE and R-Squared Errors
# 2. WAP to perform decision tree regression using boston dataset and find RME and R-Squared Errors
